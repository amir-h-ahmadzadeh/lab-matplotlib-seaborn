# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2
df = pd.DataFrame([x,y,z], index=['x','y','z']).T
df
# Out:
#      x    y     z
# 0    0    0     0
# 1    1    2     1
# 2    2    4     4
# 3    3    6     9
# 4    4    8    16
# ..  ..  ...   ...
# 95  95  190  9025
# 96  96  192  9216
# 97  97  194  9409
# 98  98  196  9604
# 99  99  198  9801
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
sns.lineplot(df, x=x, y=y)
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.lineplot(df, x=x, y=z)
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, axs = plt.subplots(nrows=1,ncols=2)
axs[0].plot(x, y,'r')
axs[1].plot(x, z,'g')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, axs = plt.subplots(nrows=1,ncols=2, figsize=(10,7))
axs[0].plot(x, y,'r')
axs[0].set_xlabel('X',color='red')
axs[0].set_ylabel('2X',color='red')

axs[1].set_xlabel('X',color='green')
axs[1].set_ylabel('X^2',color='green')
axs[1].plot(x, z,'g')
fig.tight_layout()
plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.arange(1,10,.1)
y = x**2
z = np.exp(x)

fig, axs = plt.subplots(2,2,figsize=(8,8))
axs[0][0].plot(x,y,'y',label='x^2')
axs[0][0].legend(loc='upper left')

axs[1][0].plot(x,y,'y',label='x^2')
axs[1][0].legend(loc='upper left')

axs[0][1].plot(x,z,'b',label='exp(x)')
axs[0][1].legend(loc='upper left')

axs[1][1].plot(x,z,'b',label='exp(x)')
axs[1][1].legend(loc='upper left')



axs[1][0].set_xscale('log')
axs[1][0].set_yscale('log')
axs[1][0].grid(True)

axs[1][1].set_xscale('log')
axs[1][1].set_yscale('log')
axs[1][1].grid(True)

fig.tight_layout()
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# Already is added to the plots

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv(r'D:\IronHack\labs\matplotlib-seaborn\lab-matplotlib-seaborn\your-code\Fitbit2.csv')
fitbit.sample(10)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 308  2016-03-10            3307   1853     14.71      20            793.000
# 117  2015-09-02            3009   1033      7.68      16            770.000
# 263  2016-01-26            3066  13073      9.71      18            790.000
# 173  2015-10-28             247   5623      4.18       2            779.000
# 355  2016-04-26            3357  17226     12.97      19            751.000
# 206  2015-11-30            4012  23313     17.32      16            550.000
# 212  2015-12-06            3072  12738      9.46      10            811.000
# 37   2015-06-14            2789  12335      9.16      35              1.245
# 153  2015-10-08            2767   7865      5.84      15              1.118
# 82   2015-07-29            3138   1068      7.94      16            634.000
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# ...

# %%
fitbit.shape
# Out:
# (367, 24)

# %%
fitbit.isnull().sum()
# Out:
# Date                          0
# Calorie burned                0
# Steps                         0
# Distance                      0
# Floors                        0
# Minutes Sedentary             0
# Minutes Lightly Active        0
# Minutes Fairly Active         0
# Minutes Very Active           0
# Activity Calories             0
# MinutesOfSleep                0
# MinutesOfBeingAwake           0
# NumberOfAwakings              0
# LengthOfRestInMinutes         0
# Distance_miles                0
# Days                          0
# Days_encoded                  0
# Work_or_Weekend               0
# Hours Sleep                   0
# Sleep efficiency              0
# Yesterday_sleep               0
# Yesterday_sleep_efficiency    0
# Months                        0
# Months_encoded                0
# dtype: int64

# %%
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
step_month = fitbit.groupby('Months_encoded').agg({'Steps':'median'})
plt.figuresize=(12,4)
sns.set_theme(style='darkgrid')
sns.lineplot(x='Months_encoded', y='Steps', data=step_month, marker='o',color='r')
plt.show()
# your code here
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
step_weekday = fitbit.groupby(['Work_or_Weekend','Months']).agg({'Calorie burned' : 'median'})
step_weekday
# Out:
#                            Calorie burned
# Work_or_Weekend Months
# 0               April              2884.0
#                 August             3035.0
#                 December           2776.5
#                 February           3103.0
#                 January            2832.5
#                 July               3042.5
#                 June               3410.5
#                 March              1305.0
#                 May                3441.0
#                 November           2853.0
#                 October            2871.0
#                 September          2815.0
# 1               April              3357.0
#                 August             3139.0
#                 December           2856.0
#                 February           2815.5
#                 January            3066.0
#                 July               3134.0
#                 June               3155.0
#                 March              3052.0
#                 May                2793.0
# ...

# %%
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='r', lw=2),
                Line2D([0], [0], color='b', lw=2)]
sns.lineplot(x='Months', 
             y='Calorie burned', 
             hue='Work_or_Weekend',
             data=step_weekday,
             markers=('*','*'),
             legend= False)
plt.xticks(rotation=45)
plt.legend(custom_lines, ['Work days', 'Weekends'],loc='lower left')
plt.show()

#Why marker doesn't work?
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
minutes_steps.iloc[:,1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\IronHack\labs\matplotlib-seaborn\lab-matplotlib-seaborn\your-code\main.ipynb Cell 26 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/IronHack/labs/matplotlib-seaborn/lab-matplotlib-seaborn/your-code/main.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> minutes_steps.iloc[:,1:]
#
# NameError: name 'minutes_steps' is not defined

# %%
minutes_steps = fitbit[['Steps','Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']]
fig, axs = plt.subplots(3,1,figsize=(6,12))
for i, col in enumerate(minutes_steps.iloc[:,1:]):
    plt.sca(axs[i])
    sns.scatterplot(data=minutes_steps, x='Steps', y=minutes_steps[col])

fig.tight_layout()
plt.show=()
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv(r"D:\IronHack\labs\matplotlib-seaborn\lab-matplotlib-seaborn\your-code\titanic.csv")
titanic.sample(10)
# Out:
#       PassengerId  Survived  Pclass                                   Name  \
# 1149         1150       NaN       2                Bentham, Miss. Lilian W
# 890           891       0.0       3                    Dooley, Mr. Patrick
# 934           935       NaN       2  Corbett, Mrs. Walter H (Irene Colvin)
# 452           453       0.0       1        Foreman, Mr. Benjamin Laventall
# 422           423       0.0       3                     Zimmerman, Mr. Leo
# 23             24       1.0       1           Sloper, Mr. William Thompson
# 126           127       0.0       3                    McMahon, Mr. Martin
# 723           724       0.0       2                Hodges, Mr. Henry Price
# 1294         1295       NaN       1                 Carrau, Mr. Jose Pedro
# 718           719       0.0       3                    McEvoy, Mr. Michael
#
#       Gender        Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 1149  female  19.000000      0      0   28404  13.000    U0        S
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic_num = titanic.select_dtypes('number')
titanic_num
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic_cat = titanic.select_dtypes(exclude='number')
titanic_cat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\IronHack\labs\matplotlib-seaborn\lab-matplotlib-seaborn\your-code\main.ipynb Cell 34 line 2
#       <a href='vscode-notebook-cell:/d%3A/IronHack/labs/matplotlib-seaborn/lab-matplotlib-seaborn/your-code/main.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> # CATEGORICAL VARIABLES
# ----> <a href='vscode-notebook-cell:/d%3A/IronHack/labs/matplotlib-seaborn/lab-matplotlib-seaborn/your-code/main.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> titanic_cat = titanic.select_dtypes(exclude='number')
#       <a href='vscode-notebook-cell:/d%3A/IronHack/labs/matplotlib-seaborn/lab-matplotlib-seaborn/your-code/main.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> titanic_cat
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.figsize=(12,6)
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(data=titanic_num,x='Age',binwidth=5)
plt.show()
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
bins = [10, 20, 50]
fig, axs = plt.subplots(3,1,figsize=(8,15))
for i, bin in enumerate(bins):
    plt.sca(axs[i])
    sns.histplot(data=titanic_num,x='Age',binwidth=bin)
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# Basically the bin size determines the range of which  falls into each bar. The wider the range, the more data points are illustrated in each bar. With trial and error process(as we have done in the above cell ),we as analysts should figure out which bin size gives us the most information about the corresponding variable. For titanic db and Age as variable, 50 as a bin size is too wide and we can't understand how data are distributed.5 or 10 are the reasonable choises fot the bin size in this data set.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

##### Is Already done ####

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic['Gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1309 entries, 0 to 1308
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 1309 non-null   object
# dtypes: object(1)
# memory usage: 10.4+ KB

# %%
titanic['Gender'].isnull().sum()
# Out:
# 0

# %%
count_gender = pd.DataFrame(titanic['Gender'].value_counts())
count_gender
# Out:
#         count
# Gender
# male      843
# female    466

# %%
# Method 1 - matplotlib
plt.bar(x=count_gender.index ,height=count_gender['count'], color='C1', width=.8)
sns.color_palette('pastel')
plt.show()

# %%
# Method 2 - seaborn
sns.reset_orig
sns.barplot(data=titanic,x=count_gender.index, y=count_gender['count'])
sns.axes_style('darkgrid') 
sns.set_style('darkgrid')
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic['Pclass']
# Out:
# 0       3
# 1       1
# 2       3
# 3       1
# 4       3
#        ..
# 1304    3
# 1305    1
# 1306    3
# 1307    3
# 1308    3
# Name: Pclass, Length: 1309, dtype: int64

# %%
titanic['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
count_Pclass= pd.DataFrame(titanic['Pclass'].value_counts())
count_Pclass
# Out:
#         count
# Pclass
# 3         709
# 1         323
# 2         277

# %%
sns.reset_orig
fig = plt.subplots(figsize=(5,6))
sns.barplot(x=count_Pclass.index, y=count_Pclass['count'])
sns.set_style(rc = {'axes.facecolor': 'lightsteelblue'})
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
age_stats = pd.DataFrame(round(titanic.describe(),2)['Age'])
age_stats_index = ['count (X100)' if i == 'count' else i for i in age_stats.index]
dt=[age_stats.loc[i]/100 if i=='count' else age_stats.loc[i] for i in age_stats.index ]
age_stats_custom = pd.DataFrame(data=dt,index=age_stats_index,columns=['Age'])
age_stats_custom
# Out:
#                 Age
# count (X100)  13.09
# mean          29.88
# std           13.45
# min            0.17
# 25%           22.00
# 50%           28.50
# 75%           37.00
# max           80.00

# %%
sns.reset_orig
fig = plt.subplots(figsize=(5,6))
sns.barplot(x=age_stats_custom.index, y=age_stats_custom['Age'])
sns.set_style(rc = {'axes.facecolor': 'lightsteelblue'})
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(x=titanic['Fare'], y=titanic['Age'], marker='.', color='r')

# %%
# Method 2 - seaborn
sns.scatterplot(data=titanic, x='Fare', y='Age', marker='*', color='r')
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.reset_orig
titanic_corr = titanic_num.corr()
mask = np.zeros_like(titanic_corr)
mask[np.triu_indices_from(mask)] = True
sns.set_style('whitegrid')
sns.heatmap(titanic_corr, mask=mask ,annot=True,cmap='RdYlGn')
# Out:
# <Axes: >

# %% [markdown]
# #### What are the most correlated features?

# %% [markdown]
# SibSp and Parch are the most correlated.

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
Age_summary_Pclass = titanic.groupby('Pclass').agg({'Age':'describe'})

# %%
Age_summary_Pclass
# Out:
#           Age
#         count       mean        std   min        25%        50%      75%   max
# Pclass
# 1       323.0  39.555048  13.863639  0.92  30.000000  40.000000  49.0000  80.0
# 2       277.0  29.977433  13.563141  0.67  22.948773  29.000000  36.5000  70.0
# 3       709.0  25.432757  10.605975  0.17  20.000000  25.315435  31.4561  74.0

# %%
Age_summary_Pclass.stack()
# Out:
#                      Age
# Pclass
# 1      count  323.000000
#        mean    39.555048
#        std     13.863639
#        min      0.920000
#        25%     30.000000
#        50%     40.000000
#        75%     49.000000
#        max     80.000000
# 2      count  277.000000
#        mean    29.977433
#        std     13.563141
#        min      0.670000
#        25%     22.948773
#        50%     29.000000
#        75%     36.500000
#        max     70.000000
# 3      count  709.000000
#        mean    25.432757
#        std     10.605975
#        min      0.170000
#        25%     20.000000
#        50%     25.315435
#        75%     31.456100
#        max     74.000000

# %%
titanic['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
??sns.barplot
# Out:
# Signature:
# sns.barplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     order=None,
#     hue_order=None,
#     estimator='mean',
#     errorbar=('ci', 95),
#     n_boot=1000,
#     units=None,
#     seed=None,
#     orient=None,
#     color=None,
#     palette=None,
#     saturation=0.75,
#     width=0.8,
#     errcolor='.26',
#     errwidth=None,
#     capsize=None,
#     dodge=True,
#     ci='deprecated',
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Show point estimates and errors as rectangular bars.
#
# A bar plot represents an estimate of central tendency for a numeric
# variable with the height of each rectangle and provides some indication of
# the uncertainty around that estimate using error bars. Bar plots include 0
# in the quantitative axis range, and they are a good choice when 0 is a
# meaningful value for the quantitative variable, and you want to make
# comparisons against it.
#
# ...

# %%
new_df = Age_summary_Pclass.stack().reset_index()

# %%
new_df
# Out:
#     Pclass level_1         Age
# 0        1   count  323.000000
# 1        1    mean   39.555048
# 2        1     std   13.863639
# 3        1     min    0.920000
# 4        1     25%   30.000000
# 5        1     50%   40.000000
# 6        1     75%   49.000000
# 7        1     max   80.000000
# 8        2   count  277.000000
# 9        2    mean   29.977433
# 10       2     std   13.563141
# 11       2     min    0.670000
# 12       2     25%   22.948773
# 13       2     50%   29.000000
# 14       2     75%   36.500000
# 15       2     max   70.000000
# 16       3   count  709.000000
# 17       3    mean   25.432757
# 18       3     std   10.605975
# 19       3     min    0.170000
# 20       3     25%   20.000000
# 21       3     50%   25.315435
# 22       3     75%   31.456100
# 23       3     max   74.000000

# %%
fig, axes = plt.subplots(nrows=titanic['Pclass'].nunique(), ncols=1)
for i in range(titanic['Pclass'].nunique()):
    axes[i].bar(data=Age_summary_Pclass.stack(),x=Age_summary_Pclass.columns.get_level_values(1),height=Age_summary_Pclass.values[1])

# %%
sns.barplot(data=new_df,x='level_1',y='Age', hue='Pclass')
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
#sns.set_style('darkgrid')
sns.histplot(data=titanic, x='Age', hue='Gender',  element="step")
plt.show()
# Out:
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\aha93\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
